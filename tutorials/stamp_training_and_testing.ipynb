# %%
from stamp.datasets import lmdb_embedding_dataset
from stamp.modeling import create_modeling_approach
from stamp.local import get_local_config
from stamp.common import setup_seed
from stamp.modeling.utils import calculate_binary_performance_metrics, calculate_multiclass_performance_metrics
from types import SimpleNamespace
import shutil
import os

local_config = get_local_config()

# %% [markdown]
# # Seeds

# %%
seed = 654
setup_seed(seed)

# %% [markdown]
# # Dataset Preparation

# %%
dataset_name = 'stress'
embedding_model_name = 'MOMENT-1-large'
embeddings_dir = local_config.datasets_dir + f'/{dataset_name}/{embedding_model_name}'

batch_size = 64

# NOTE: For debugging, set prefetch_factor=None and num_workers=1
params = SimpleNamespace(
    dataset_name=dataset_name,
    dataset_dir=embeddings_dir,
    batch_size=batch_size,
    temporal_channel_selection=None,
    seed=seed
)

loaddataset = lmdb_embedding_dataset.LoadDataset(params)

data_loader = loaddataset.get_data_loader()
n_classes = loaddataset.dataset_params['n_classes']
n_temporal_channels = loaddataset.dataset_params['n_temporal_channels']
n_spatial_channels = loaddataset.dataset_params['n_spatial_channels']
n_samples = loaddataset.dataset_params['n_samples']
# Out:
# Temporal channel selection: None
# Loaded 1343 keys from stored __keys__
# Temporal channel selection: None
# Loaded 172 keys from stored __keys__
# Temporal channel selection: None
# Loaded 192 keys from stored __keys__
# 1343 172 192
# 1707

# %% [markdown]
# # Model Configuration

# %%
if n_classes == 1:
    problem_type = 'binary'
else:
    problem_type = 'multiclass'

dropout_rate = 0.3
device = 'cuda:3' # Use 'cuda:k' for GPU k

# NOTE: This config includes the default STAMP hyperparameters; modify as needed
modeling_approach_config = {
    'modeling_approach_name': 'STAMPModelingApproach',
    'params': {
            "problem_type": "binary",
            "n_classes": 1,
            "device": device,
            "n_temporal_channels": 5,
            "n_spatial_channels": 20,
            "temporal_channel_selection": None,
            "label_smoothing": 0.1,
            "use_batch_norm": False,
            "use_instance_norm": True,
            "use_gradient_clipping": True,
            "input_dim": 1024,
            "D": 128,
            "initial_proj_params": {
                "type": "full",
                "dropout_rate": 0.3
            },
            "pe_params": {
                "pe_type": "basic",
                "use_token_positional_embeddings": True,
                "use_spatial_positional_embeddings": True,
                "use_temporal_positional_embeddings": True
            },
            "transformer_params": None,
            "gated_mlp_params": {
                "type": "criss_cross",
                "n_layers": 8,
                "dim_feedforward": 256,
                "dropout_rate": 0.3,
                "combination_mode": "concat",
                "recurrent": False
            },
            "encoder_aggregation": "attention_pooling",
            "mhap_params": {
                "A": 4,
                "dropout_rate": 0.3,
                "n_queries_per_head": 8,
                "query_combination": "weighted_sum",
                "lambda_for_residual": 0.1
            },
            "final_classifier_params": None,
            "n_epochs": 50,
            "train_batch_size": 64,
            "test_batch_size": 64,
            "min_epoch": 0,
            "use_tqdm": False,
            "store_attention_weights": False,
            "debug_size": None,
            "lr_params": {
                "use_scheduler": True,
                "scheduler_type": "one_cycle",
                "initial_lr": 5e-05,
                "max_lr": 0.0003
            },
            "optimizer_params": {
                "optimizer_name": "adamw",
                "betas": [
                    0.9,
                    0.999
                ],
                "eps": 1e-08,
                "weight_decay": 0.05
            },
            "early_stopping_params": {
                "name": "EarlyStopping",
                "patience": 1000,
                "min_delta": 0.001,
                "tmp_dir": local_config.tmp_dir + '/stamp'
            },
            "checkpointing_params": None
    }
}

# %%
shutil.rmtree(modeling_approach_config['params']['early_stopping_params']['tmp_dir'], ignore_errors=True)
os.mkdir(modeling_approach_config['params']['early_stopping_params']['tmp_dir'])

# %% [markdown]
# # Model Setup

# %%
modeling_approach = create_modeling_approach(modeling_approach_config=modeling_approach_config)
modeling_approach.random_seed = seed
# Out:
# WARNING:p-22670:t-140171588699968:jit_analysis.py:_warn_unsupported_ops:Unsupported operator aten::mul encountered 22 time(s)
# WARNING:p-22670:t-140171588699968:jit_analysis.py:_warn_unsupported_ops:Unsupported operator aten::embedding encountered 3 time(s)
# WARNING:p-22670:t-140171588699968:jit_analysis.py:_warn_unsupported_ops:Unsupported operator aten::repeat encountered 1 time(s)
# WARNING:p-22670:t-140171588699968:jit_analysis.py:_warn_unsupported_ops:Unsupported operator aten::repeat_interleave encountered 1 time(s)
# WARNING:p-22670:t-140171588699968:jit_analysis.py:_warn_unsupported_ops:Unsupported operator aten::sum encountered 5 time(s)
# WARNING:p-22670:t-140171588699968:jit_analysis.py:_warn_unsupported_ops:Unsupported operator aten::add encountered 10 time(s)
# WARNING:p-22670:t-140171588699968:jit_analysis.py:_warn_unsupported_ops:Unsupported operator aten::gelu encountered 8 time(s)
# WARNING:p-22670:t-140171588699968:jit_analysis.py:_warn_unsupported_ops:Unsupported operator aten::mean encountered 1 time(s)
# WARNING:p-22670:t-140171588699968:jit_analysis.py:_warn_unsupported_ops:Unsupported operator aten::div encountered 1 time(s)
# WARNING:p-22670:t-140171588699968:jit_analysis.py:_warn_unsupported_ops:Unsupported operator aten::softmax encountered 2 time(s)
# WARNING:p-22670:t-140171588699968:jit_analysis.py:_warn_unsupported_ops:Unsupported operator aten::isnan encountered 1 time(s)
# WARNING:p-22670:t-140171588699968:jit_analysis.py:_warn_unsupported_ops:Unsupported operator aten::where encountered 1 time(s)
# WARNING:p-22670:t-140171588699968:jit_analysis.py:_warn_uncalled_mods:The following submodules of the model were never called during the trace of the graph. They may be unused, or they were accessed by direct calls to .forward() or via other python methods. In the latter case they will have zeros for statistics, though their statistics will still contribute to their parent calling module.
# dropout

# %%
modeling_approach.model
# Out:
# STAMP(
#   (data_norm): InstanceNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (linear): Sequential(
#     (0): Dropout(p=0.3, inplace=False)
#     (1): Linear(in_features=1024, out_features=128, bias=True)
#   )
#   (pos_embed): Embedding(100, 128)
#   (spatial_embed): Embedding(20, 128)
#   (temporal_embed): Embedding(5, 128)
#   (gated_mlp): ModuleList(
#     (0-7): 8 x CrissCrossGatedMLPBlock(
#       (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (proj_1): Linear(in_features=128, out_features=256, bias=True)
#       (gelu): GELU(approximate='none')
#       (sgu_temporal): SpatialGatingUnit(
#         (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (spatial_proj): Linear(in_features=5, out_features=5, bias=True)
#       )
#       (sgu_spatial): SpatialGatingUnit(
#         (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (spatial_proj): Linear(in_features=20, out_features=20, bias=True)
#       )
#       (proj_2): Linear(in_features=256, out_features=128, bias=True)
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#   )
#   (multi_head_attention_pooling): MultiHeadAttentionPooling(
#     (dropout): Dropout(p=0.3, inplace=False)
#     (W): ModuleList(
#       (0-3): 4 x Linear(in_features=128, out_features=32, bias=False)
#     )
#     (out_proj): Linear(in_features=128, out_features=128, bias=True)
#     (softmax): Softmax(dim=3)
#   )
#   (classifier): Linear(in_features=128, out_features=1, bias=True)
# )

# %%
print("Parameters per layer:")
for name, module in modeling_approach.model.named_modules():
    if list(module.parameters()):  # Check if the module has any parameters
        param_count = sum(p.numel() for p in module.parameters())
        print(f"  {name}: {param_count} parameters")
# Out:
# Parameters per layer:
#   : 720401 parameters
#   data_norm: 2048 parameters
#   linear: 131200 parameters
#   linear.1: 131200 parameters
#   pos_embed: 12800 parameters
#   spatial_embed: 2560 parameters
#   temporal_embed: 640 parameters
#   gated_mlp: 537104 parameters
#   gated_mlp.0: 67138 parameters
#   gated_mlp.0.norm: 256 parameters
#   gated_mlp.0.proj_1: 33024 parameters
#   gated_mlp.0.sgu_temporal: 286 parameters
#   gated_mlp.0.sgu_temporal.norm: 256 parameters
#   gated_mlp.0.sgu_temporal.spatial_proj: 30 parameters
#   gated_mlp.0.sgu_spatial: 676 parameters
#   gated_mlp.0.sgu_spatial.norm: 256 parameters
#   gated_mlp.0.sgu_spatial.spatial_proj: 420 parameters
#   gated_mlp.0.proj_2: 32896 parameters
#   gated_mlp.1: 67138 parameters
#   gated_mlp.1.norm: 256 parameters
#   gated_mlp.1.proj_1: 33024 parameters
#   gated_mlp.1.sgu_temporal: 286 parameters
#   gated_mlp.1.sgu_temporal.norm: 256 parameters
#   gated_mlp.1.sgu_temporal.spatial_proj: 30 parameters
#   gated_mlp.1.sgu_spatial: 676 parameters
#   gated_mlp.1.sgu_spatial.norm: 256 parameters
#   gated_mlp.1.sgu_spatial.spatial_proj: 420 parameters
#   gated_mlp.1.proj_2: 32896 parameters
#   gated_mlp.2: 67138 parameters
#   gated_mlp.2.norm: 256 parameters
#   gated_mlp.2.proj_1: 33024 parameters
#   gated_mlp.2.sgu_temporal: 286 parameters
#   gated_mlp.2.sgu_temporal.norm: 256 parameters
#   gated_mlp.2.sgu_temporal.spatial_proj: 30 parameters
#   gated_mlp.2.sgu_spatial: 676 parameters
#   gated_mlp.2.sgu_spatial.norm: 256 parameters
#   gated_mlp.2.sgu_spatial.spatial_proj: 420 parameters
#   gated_mlp.2.proj_2: 32896 parameters
#   gated_mlp.3: 67138 parameters
#   gated_mlp.3.norm: 256 parameters
#   gated_mlp.3.proj_1: 33024 parameters
#   gated_mlp.3.sgu_temporal: 286 parameters
#   gated_mlp.3.sgu_temporal.norm: 256 parameters
#   gated_mlp.3.sgu_temporal.spatial_proj: 30 parameters
#   gated_mlp.3.sgu_spatial: 676 parameters
#   gated_mlp.3.sgu_spatial.norm: 256 parameters
#   gated_mlp.3.sgu_spatial.spatial_proj: 420 parameters
#   gated_mlp.3.proj_2: 32896 parameters
#   gated_mlp.4: 67138 parameters
#   gated_mlp.4.norm: 256 parameters
#   gated_mlp.4.proj_1: 33024 parameters
#   gated_mlp.4.sgu_temporal: 286 parameters
#   gated_mlp.4.sgu_temporal.norm: 256 parameters
#   gated_mlp.4.sgu_temporal.spatial_proj: 30 parameters
#   gated_mlp.4.sgu_spatial: 676 parameters
#   gated_mlp.4.sgu_spatial.norm: 256 parameters
#   gated_mlp.4.sgu_spatial.spatial_proj: 420 parameters
#   gated_mlp.4.proj_2: 32896 parameters
#   gated_mlp.5: 67138 parameters
#   gated_mlp.5.norm: 256 parameters
#   gated_mlp.5.proj_1: 33024 parameters
#   gated_mlp.5.sgu_temporal: 286 parameters
#   gated_mlp.5.sgu_temporal.norm: 256 parameters
#   gated_mlp.5.sgu_temporal.spatial_proj: 30 parameters
#   gated_mlp.5.sgu_spatial: 676 parameters
#   gated_mlp.5.sgu_spatial.norm: 256 parameters
#   gated_mlp.5.sgu_spatial.spatial_proj: 420 parameters
#   gated_mlp.5.proj_2: 32896 parameters
#   gated_mlp.6: 67138 parameters
#   gated_mlp.6.norm: 256 parameters
#   gated_mlp.6.proj_1: 33024 parameters
#   gated_mlp.6.sgu_temporal: 286 parameters
#   gated_mlp.6.sgu_temporal.norm: 256 parameters
#   gated_mlp.6.sgu_temporal.spatial_proj: 30 parameters
#   gated_mlp.6.sgu_spatial: 676 parameters
#   gated_mlp.6.sgu_spatial.norm: 256 parameters
#   gated_mlp.6.sgu_spatial.spatial_proj: 420 parameters
#   gated_mlp.6.proj_2: 32896 parameters
#   gated_mlp.7: 67138 parameters
#   gated_mlp.7.norm: 256 parameters
#   gated_mlp.7.proj_1: 33024 parameters
#   gated_mlp.7.sgu_temporal: 286 parameters
#   gated_mlp.7.sgu_temporal.norm: 256 parameters
#   gated_mlp.7.sgu_temporal.spatial_proj: 30 parameters
#   gated_mlp.7.sgu_spatial: 676 parameters
#   gated_mlp.7.sgu_spatial.norm: 256 parameters
#   gated_mlp.7.sgu_spatial.spatial_proj: 420 parameters
#   gated_mlp.7.proj_2: 32896 parameters
#   multi_head_attention_pooling: 33920 parameters
#   multi_head_attention_pooling.W: 16384 parameters
#   multi_head_attention_pooling.W.0: 4096 parameters
#   multi_head_attention_pooling.W.1: 4096 parameters
#   multi_head_attention_pooling.W.2: 4096 parameters
#   multi_head_attention_pooling.W.3: 4096 parameters
#   multi_head_attention_pooling.out_proj: 16512 parameters
#   classifier: 129 parameters

# %% [markdown]
# # Training and Validation

# %%
modeling_approach.train(
    data_loader['train'],
    data_loader['val']
)
# Out:
# Epoch: 0
# Training...
# train_main_loss: 0.5668, val_loss: 0.6294
# train_balanced_acc: 0.5000, val_balanced_acc: 0.5000
# train_pr_auc: 0.2559, val_pr_auc: 0.3909
# train_roc_auc: 0.5171, val_roc_auc: 0.5934
# Val CM:
# [[124   0]
#  [ 48   0]]
# Epoch: 1
# Training...
# train_main_loss: 0.5619, val_loss: 0.6270
# train_balanced_acc: 0.5000, val_balanced_acc: 0.5000
# train_pr_auc: 0.2740, val_pr_auc: 0.4155
# train_roc_auc: 0.5266, val_roc_auc: 0.6321
# Val CM:
# [[124   0]
#  [ 48   0]]
# Saving best checkpoint at epoch 1...
# Epoch: 2
# Training...
# train_main_loss: 0.5648, val_loss: 0.6224
# train_balanced_acc: 0.5000, val_balanced_acc: 0.5000
# train_pr_auc: 0.2518, val_pr_auc: 0.4555
# train_roc_auc: 0.4873, val_roc_auc: 0.6858
# Val CM:
# [[124   0]
#  [ 48   0]]
# Saving best checkpoint at epoch 2...
# Epoch: 3
# Training...
# train_main_loss: 0.5625, val_loss: 0.6290
# train_balanced_acc: 0.5000, val_balanced_acc: 0.5000
# train_pr_auc: 0.2565, val_pr_auc: 0.5325
# train_roc_auc: 0.5168, val_roc_auc: 0.7515
# Val CM:
# [[124   0]
#  [ 48   0]]
# Saving best checkpoint at epoch 3...
# Epoch: 4
# Training...
# train_main_loss: 0.5638, val_loss: 0.6294
# train_balanced_acc: 0.5000, val_balanced_acc: 0.5000
# train_pr_auc: 0.2655, val_pr_auc: 0.6010
# train_roc_auc: 0.5248, val_roc_auc: 0.8016
# Val CM:
# [[124   0]
#  [ 48   0]]
# Saving best checkpoint at epoch 4...
# Epoch: 5
# Training...
# train_main_loss: 0.5684, val_loss: 0.6072
# train_balanced_acc: 0.5000, val_balanced_acc: 0.5000
# train_pr_auc: 0.2803, val_pr_auc: 0.6360
# train_roc_auc: 0.5300, val_roc_auc: 0.8234
# Val CM:
# [[124   0]
#  [ 48   0]]
# Saving best checkpoint at epoch 5...
# Epoch: 6
# Training...
# train_main_loss: 0.5512, val_loss: 0.6050
# train_balanced_acc: 0.5000, val_balanced_acc: 0.5000
# train_pr_auc: 0.3409, val_pr_auc: 0.6382
# train_roc_auc: 0.6157, val_roc_auc: 0.8199
# Val CM:
# [[124   0]
#  [ 48   0]]
# Epoch: 7
# Training...
# train_main_loss: 0.5475, val_loss: 0.6010
# train_balanced_acc: 0.5000, val_balanced_acc: 0.5000
# train_pr_auc: 0.3652, val_pr_auc: 0.6269
# train_roc_auc: 0.6288, val_roc_auc: 0.7920
# Val CM:
# [[124   0]
#  [ 48   0]]
# Epoch: 8
# Training...
# train_main_loss: 0.5213, val_loss: 0.5337
# train_balanced_acc: 0.5268, val_balanced_acc: 0.5312
# train_pr_auc: 0.4296, val_pr_auc: 0.6361
# train_roc_auc: 0.6872, val_roc_auc: 0.7935
# Val CM:
# [[124   0]
#  [ 45   3]]
# Epoch: 9
# Training...
# train_main_loss: 0.4928, val_loss: 0.5420
# train_balanced_acc: 0.5803, val_balanced_acc: 0.5312
# train_pr_auc: 0.4950, val_pr_auc: 0.6839
# train_roc_auc: 0.7379, val_roc_auc: 0.8295
# Val CM:
# [[124   0]
#  [ 45   3]]
# Saving best checkpoint at epoch 9...
# Epoch: 10
# Training...
# train_main_loss: 0.4653, val_loss: 0.4477
# train_balanced_acc: 0.6131, val_balanced_acc: 0.6657
# train_pr_auc: 0.5399, val_pr_auc: 0.6746
# train_roc_auc: 0.7824, val_roc_auc: 0.8306
# Val CM:
# [[116   8]
#  [ 29  19]]
# Saving best checkpoint at epoch 10...
# Epoch: 11
# Training...
# train_main_loss: 0.4849, val_loss: 0.5225
# train_balanced_acc: 0.6592, val_balanced_acc: 0.5833
# train_pr_auc: 0.5562, val_pr_auc: 0.7319
# train_roc_auc: 0.7601, val_roc_auc: 0.8485
# Val CM:
# [[124   0]
#  [ 40   8]]
# Saving best checkpoint at epoch 11...
# Epoch: 12
# Training...
# train_main_loss: 0.4341, val_loss: 0.4301
# train_balanced_acc: 0.6508, val_balanced_acc: 0.6835
# train_pr_auc: 0.6271, val_pr_auc: 0.7777
# train_roc_auc: 0.8099, val_roc_auc: 0.8690
# Val CM:
# [[123   1]
#  [ 30  18]]
# Saving best checkpoint at epoch 12...
# Epoch: 13
# Training...
# train_main_loss: 0.3806, val_loss: 0.4028
# train_balanced_acc: 0.7038, val_balanced_acc: 0.7171
# train_pr_auc: 0.7136, val_pr_auc: 0.7814
# train_roc_auc: 0.8637, val_roc_auc: 0.8674
# Val CM:
# [[121   3]
#  [ 26  22]]
# Epoch: 14
# Training...
# train_main_loss: 0.3417, val_loss: 0.5119
# train_balanced_acc: 0.7807, val_balanced_acc: 0.6146
# train_pr_auc: 0.7839, val_pr_auc: 0.8118
# train_roc_auc: 0.8867, val_roc_auc: 0.8957
# Val CM:
# [[124   0]
#  [ 37  11]]
# Saving best checkpoint at epoch 14...
# Epoch: 15
# Training...
# train_main_loss: 0.3193, val_loss: 0.6494
# train_balanced_acc: 0.7852, val_balanced_acc: 0.6250
# train_pr_auc: 0.8039, val_pr_auc: 0.7947
# train_roc_auc: 0.9064, val_roc_auc: 0.8789
# Val CM:
# [[124   0]
#  [ 36  12]]
# Epoch: 16
# Training...
# train_main_loss: 0.3000, val_loss: 0.3699
# train_balanced_acc: 0.8001, val_balanced_acc: 0.7171
# train_pr_auc: 0.8187, val_pr_auc: 0.8106
# train_roc_auc: 0.9198, val_roc_auc: 0.8973
# Val CM:
# [[121   3]
#  [ 26  22]]
# Saving best checkpoint at epoch 16...
# Epoch: 17
# Training...
# train_main_loss: 0.3370, val_loss: 0.8660
# train_balanced_acc: 0.7876, val_balanced_acc: 0.5625
# train_pr_auc: 0.7891, val_pr_auc: 0.8221
# train_roc_auc: 0.9045, val_roc_auc: 0.8978
# Val CM:
# [[124   0]
#  [ 42   6]]
# Epoch: 18
# Training...
# train_main_loss: 0.3021, val_loss: 0.5529
# train_balanced_acc: 0.8140, val_balanced_acc: 0.6562
# train_pr_auc: 0.8277, val_pr_auc: 0.7997
# train_roc_auc: 0.9174, val_roc_auc: 0.8901
# Val CM:
# [[124   0]
#  [ 33  15]]
# Epoch: 19
# Training...
# train_main_loss: 0.2211, val_loss: 0.5718
# train_balanced_acc: 0.8601, val_balanced_acc: 0.6771
# train_pr_auc: 0.9042, val_pr_auc: 0.8108
# train_roc_auc: 0.9574, val_roc_auc: 0.8849
# Val CM:
# [[124   0]
#  [ 31  17]]
# Epoch: 20
# Training...
# train_main_loss: 0.1674, val_loss: 0.4958
# train_balanced_acc: 0.9072, val_balanced_acc: 0.6875
# train_pr_auc: 0.9449, val_pr_auc: 0.8309
# train_roc_auc: 0.9766, val_roc_auc: 0.9031
# Val CM:
# [[124   0]
#  [ 30  18]]
# Saving best checkpoint at epoch 20...
# Epoch: 21
# Training...
# train_main_loss: 0.1490, val_loss: 0.8913
# train_balanced_acc: 0.9162, val_balanced_acc: 0.6562
# train_pr_auc: 0.9574, val_pr_auc: 0.7904
# train_roc_auc: 0.9814, val_roc_auc: 0.8842
# Val CM:
# [[124   0]
#  [ 33  15]]
# Epoch: 22
# Training...
# train_main_loss: 0.1085, val_loss: 0.7299
# train_balanced_acc: 0.9420, val_balanced_acc: 0.6835
# train_pr_auc: 0.9760, val_pr_auc: 0.8066
# train_roc_auc: 0.9907, val_roc_auc: 0.8950
# Val CM:
# [[123   1]
#  [ 30  18]]
# Epoch: 23
# Training...
# train_main_loss: 0.1266, val_loss: 0.7142
# train_balanced_acc: 0.9345, val_balanced_acc: 0.7147
# train_pr_auc: 0.9665, val_pr_auc: 0.8123
# train_roc_auc: 0.9866, val_roc_auc: 0.8938
# Val CM:
# [[123   1]
#  [ 27  21]]
# Epoch: 24
# Training...
# train_main_loss: 0.1053, val_loss: 0.7406
# train_balanced_acc: 0.9410, val_balanced_acc: 0.7043
# train_pr_auc: 0.9776, val_pr_auc: 0.8226
# train_roc_auc: 0.9907, val_roc_auc: 0.9017
# Val CM:
# [[123   1]
#  [ 28  20]]
# Epoch: 25
# Training...
# train_main_loss: 0.0916, val_loss: 1.2822
# train_balanced_acc: 0.9534, val_balanced_acc: 0.6667
# train_pr_auc: 0.9816, val_pr_auc: 0.8045
# train_roc_auc: 0.9934, val_roc_auc: 0.8871
# Val CM:
# [[124   0]
#  [ 32  16]]
# Epoch: 26
# Training...
# train_main_loss: 0.0554, val_loss: 1.0846
# train_balanced_acc: 0.9692, val_balanced_acc: 0.6875
# train_pr_auc: 0.9933, val_pr_auc: 0.8148
# train_roc_auc: 0.9975, val_roc_auc: 0.8931
# Val CM:
# [[124   0]
#  [ 30  18]]
# Epoch: 27
# Training...
# train_main_loss: 0.0534, val_loss: 0.7938
# train_balanced_acc: 0.9727, val_balanced_acc: 0.7043
# train_pr_auc: 0.9941, val_pr_auc: 0.7917
# train_roc_auc: 0.9979, val_roc_auc: 0.8893
# Val CM:
# [[123   1]
#  [ 28  20]]
# Epoch: 28
# Training...
# train_main_loss: 0.0371, val_loss: 1.1077
# train_balanced_acc: 0.9747, val_balanced_acc: 0.6939
# train_pr_auc: 0.9972, val_pr_auc: 0.7812
# train_roc_auc: 0.9990, val_roc_auc: 0.8718
# Val CM:
# [[123   1]
#  [ 29  19]]
# Epoch: 29
# Training...
# train_main_loss: 0.0402, val_loss: 1.2757
# train_balanced_acc: 0.9816, val_balanced_acc: 0.6731
# train_pr_auc: 0.9966, val_pr_auc: 0.8017
# train_roc_auc: 0.9988, val_roc_auc: 0.8847
# Val CM:
# [[123   1]
#  [ 31  17]]
# Epoch: 30
# Training...
# train_main_loss: 0.0242, val_loss: 1.0172
# train_balanced_acc: 0.9866, val_balanced_acc: 0.7043
# train_pr_auc: 0.9988, val_pr_auc: 0.8023
# train_roc_auc: 0.9996, val_roc_auc: 0.8876
# Val CM:
# [[123   1]
#  [ 28  20]]
# Epoch: 31
# Training...
# train_main_loss: 0.0213, val_loss: 1.3953
# train_balanced_acc: 0.9931, val_balanced_acc: 0.6731
# train_pr_auc: 0.9991, val_pr_auc: 0.7925
# train_roc_auc: 0.9997, val_roc_auc: 0.8802
# Val CM:
# [[123   1]
#  [ 31  17]]
# Epoch: 32
# Training...
# train_main_loss: 0.0112, val_loss: 1.1518
# train_balanced_acc: 0.9950, val_balanced_acc: 0.7107
# train_pr_auc: 0.9998, val_pr_auc: 0.7824
# train_roc_auc: 0.9999, val_roc_auc: 0.8737
# Val CM:
# [[122   2]
#  [ 27  21]]
# Epoch: 33
# Training...
# train_main_loss: 0.0143, val_loss: 1.5554
# train_balanced_acc: 0.9950, val_balanced_acc: 0.6835
# train_pr_auc: 0.9996, val_pr_auc: 0.7810
# train_roc_auc: 0.9999, val_roc_auc: 0.8681
# Val CM:
# [[123   1]
#  [ 30  18]]
# Epoch: 34
# Training...
# train_main_loss: 0.0108, val_loss: 2.3455
# train_balanced_acc: 0.9960, val_balanced_acc: 0.6250
# train_pr_auc: 0.9998, val_pr_auc: 0.7751
# train_roc_auc: 0.9999, val_roc_auc: 0.8695
# Val CM:
# [[124   0]
#  [ 36  12]]
# Epoch: 35
# Training...
# train_main_loss: 0.0095, val_loss: 1.5446
# train_balanced_acc: 0.9965, val_balanced_acc: 0.6835
# train_pr_auc: 0.9998, val_pr_auc: 0.7841
# train_roc_auc: 0.9999, val_roc_auc: 0.8705
# Val CM:
# [[123   1]
#  [ 30  18]]
# Epoch: 36
# Training...
# train_main_loss: 0.0073, val_loss: 1.8932
# train_balanced_acc: 0.9970, val_balanced_acc: 0.6731
# train_pr_auc: 0.9999, val_pr_auc: 0.7832
# train_roc_auc: 1.0000, val_roc_auc: 0.8681
# Val CM:
# [[123   1]
#  [ 31  17]]
# Epoch: 37
# Training...
# train_main_loss: 0.0066, val_loss: 1.6358
# train_balanced_acc: 0.9965, val_balanced_acc: 0.6835
# train_pr_auc: 1.0000, val_pr_auc: 0.7894
# train_roc_auc: 1.0000, val_roc_auc: 0.8710
# Val CM:
# [[123   1]
#  [ 30  18]]
# Epoch: 38
# Training...
# train_main_loss: 0.0044, val_loss: 1.3574
# train_balanced_acc: 0.9970, val_balanced_acc: 0.7147
# train_pr_auc: 1.0000, val_pr_auc: 0.7926
# train_roc_auc: 1.0000, val_roc_auc: 0.8750
# Val CM:
# [[123   1]
#  [ 27  21]]
# Epoch: 39
# Training...
# train_main_loss: 0.0073, val_loss: 1.5505
# train_balanced_acc: 0.9995, val_balanced_acc: 0.6835
# train_pr_auc: 1.0000, val_pr_auc: 0.7922
# train_roc_auc: 1.0000, val_roc_auc: 0.8733
# Val CM:
# [[123   1]
#  [ 30  18]]
# Epoch: 40
# Training...
# train_main_loss: 0.0030, val_loss: 1.9948
# train_balanced_acc: 1.0000, val_balanced_acc: 0.6771
# train_pr_auc: 1.0000, val_pr_auc: 0.7894
# train_roc_auc: 1.0000, val_roc_auc: 0.8743
# Val CM:
# [[124   0]
#  [ 31  17]]
# Epoch: 41
# Training...
# train_main_loss: 0.0064, val_loss: 1.5168
# train_balanced_acc: 0.9985, val_balanced_acc: 0.6939
# train_pr_auc: 0.9998, val_pr_auc: 0.7877
# train_roc_auc: 0.9999, val_roc_auc: 0.8735
# Val CM:
# [[123   1]
#  [ 29  19]]
# Epoch: 42
# Training...
# train_main_loss: 0.0080, val_loss: 1.4466
# train_balanced_acc: 0.9965, val_balanced_acc: 0.7147
# train_pr_auc: 0.9996, val_pr_auc: 0.7841
# train_roc_auc: 0.9999, val_roc_auc: 0.8718
# Val CM:
# [[123   1]
#  [ 27  21]]
# Epoch: 43
# Training...
# train_main_loss: 0.0029, val_loss: 1.7444
# train_balanced_acc: 0.9995, val_balanced_acc: 0.6835
# train_pr_auc: 1.0000, val_pr_auc: 0.7829
# train_roc_auc: 1.0000, val_roc_auc: 0.8710
# Val CM:
# [[123   1]
#  [ 30  18]]
# Epoch: 44
# Training...
# train_main_loss: 0.0019, val_loss: 1.6726
# train_balanced_acc: 1.0000, val_balanced_acc: 0.6835
# train_pr_auc: 1.0000, val_pr_auc: 0.7839
# train_roc_auc: 1.0000, val_roc_auc: 0.8728
# Val CM:
# [[123   1]
#  [ 30  18]]
# Epoch: 45
# Training...
# train_main_loss: 0.0019, val_loss: 1.5859
# train_balanced_acc: 1.0000, val_balanced_acc: 0.6939
# train_pr_auc: 1.0000, val_pr_auc: 0.7842
# train_roc_auc: 1.0000, val_roc_auc: 0.8730
# Val CM:
# [[123   1]
#  [ 29  19]]
# Epoch: 46
# Training...
# train_main_loss: 0.0033, val_loss: 1.7300
# train_balanced_acc: 0.9995, val_balanced_acc: 0.6835
# train_pr_auc: 1.0000, val_pr_auc: 0.7842
# train_roc_auc: 1.0000, val_roc_auc: 0.8730
# Val CM:
# [[123   1]
#  [ 30  18]]
# Epoch: 47
# Training...
# train_main_loss: 0.0021, val_loss: 1.7190
# train_balanced_acc: 0.9995, val_balanced_acc: 0.6835
# train_pr_auc: 1.0000, val_pr_auc: 0.7837
# train_roc_auc: 1.0000, val_roc_auc: 0.8728
# Val CM:
# [[123   1]
#  [ 30  18]]
# Epoch: 48
# Training...
# train_main_loss: 0.0056, val_loss: 1.7329
# train_balanced_acc: 0.9970, val_balanced_acc: 0.6835
# train_pr_auc: 0.9999, val_pr_auc: 0.7836
# train_roc_auc: 1.0000, val_roc_auc: 0.8728
# Val CM:
# [[123   1]
#  [ 30  18]]
# Epoch: 49
# Training...
# train_main_loss: 0.0029, val_loss: 1.7320
# train_balanced_acc: 0.9995, val_balanced_acc: 0.6835
# train_pr_auc: 1.0000, val_pr_auc: 0.7836
# train_roc_auc: 1.0000, val_roc_auc: 0.8728
# Val CM:
# [[123   1]
#  [ 30  18]]
# Loading best checkpoint from epoch 20...

# %% [markdown]
# # Evaluation on Test Set

# %%
pred_df, extra_info = modeling_approach.predict(
    test_data_loader=data_loader['test']
)

# %%
prob_df = extra_info['prob_df']
truths = extra_info['test_labels']
probs = prob_df.values
preds = pred_df.values

# %%
if problem_type == 'multiclass':
    balanced_acc, cohen_kappa, weighted_f1, cm = calculate_multiclass_performance_metrics(truths=truths, preds=preds)
    print(f'Balanced accuracy: {balanced_acc}')
    print(f'Cohen kappa: {cohen_kappa}')
    print(f'Weighted F1: {weighted_f1}')
else:
    balanced_acc, pr_auc, roc_auc, cm = calculate_binary_performance_metrics(truths=truths, probs=probs, preds=preds)
    print(f'Balanced accuracy: {balanced_acc}')
    print(f'AUROC: {roc_auc}')
    print(f'AUC-PR: {pr_auc}')
# Out:
# Balanced accuracy: 0.6597222222222222
# AUROC: 0.8039641203703705
# AUC-PR: 0.632623372317013
